# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/ai-personalized-dashboard/blob/main/Built_in_Functions_%26_IF_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(round(4.3343,2))
print(round(5.564))
print(round(5.322))
# Out:
# 4.33
# 6
# 5

# %%
g = divmod(34,9)
print(g)
print(type)
g[0]
g[1]
# Out:
# (3, 7)
# <class 'type'>
# 7

# %%
isinstance(3,int)
isinstance(3.4,float)
# Out:
# True

# %%
pow(2,4)
2**4
# Out:
# 16

# %%
print("The name is " + input("Enter your name: "))
# Out:
# Enter your name: Asim ALi
# The name is Asim ALi

# %%
pow?

# %%
pow??

# %%
help(pow)
# Out:
# Help on built-in function pow in module builtins:
#
# pow(base, exp, mod=None)
#     Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
#     Some types, such as ints, are able to use a more efficient algorithm when
#     invoked using the three argument form.

# %%
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))

if a > b:
    print(a, "is largest")
else:
    print(b, "is largest")
# Out:
# Enter a number: 12
# Enter another number: 11
# 12 is largest

# %%
a = float(input("Enter a number: "))
b = float(input("Enter another number: "))

if a > b:
    print(a, "is largest")
elif a == b:
    print("Both are equal")
else:
    print(b, "is largest")
# Out:
# Enter a number: 14
# Enter another number: 11
# 14.0 is largest

# %%
a = float(input("Enter a number: "))
b = float(input("Enter another number: "))
print(a) if a > b else print("=") if a == b else print(b)
# Out:
# Enter a number: 12
# Enter another number: 12
# =

# %%
marks = int(input("Enter your marks: "))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 80 and marks < 90:
    print("Grade: B")
elif marks >= 70 and marks < 80:
    print("Grade: C")
elif marks >= 60 and marks < 70:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter your marks: 85
# Grade: B

# %%
num = int(input("Enter a number: "))

if num > 0:
    if num % 2 == 0:
        print("The number is positive and even")
    else:
        print("The number is positive but odd")
else:
    print("The number is negative or zero")
# Out:
# Enter a number: 12
# The number is positive and even

# %%
marks = int(input("Input your percentage: "))
income = float(input("Enter your Monthly Income: "))

if marks >= 85:
    if income <= 300000:
        print("Full Scholarship")
    else:
        print("Half Scholarship")
elif marks >= 70 and marks < 85:
    if income <= 200000:
        print("Half Scholarship")
    else:
        print("No Scholarship")
else:
    print("No Scholarship")
# Out:
# Input your percentage: 78
# Enter your Monthly Income: 2000000
# No Scholarship

# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/ai-personalized-dashboard/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "python is good programming language"
t = "it is best for data science"
v = s+" "+t
print(v)
# Out:
# python is good programming language it is best for data science

# %%
price = 30
book = "the price of this book is:"
v = book+ " " + str(price)
print(v)
print(book , price)
# Out:
# the price of this book is: 30
# the price of this book is: 30

# %%
print("""
This is multie line way to print a large string message
""")
# Out:
# This is multie line way to print a large string message

# %%
s = "How are doing today as compared to yesterday"
print(s[0:5])
print(s[0:15:2])
print(s[-1:-10:-1])
# Out:
# How a
# Hwaedigt
# yadretsey

# %%
a = "    asdf   sdfasdf             adfegds   "
b = a.strip()
print(b)
# Out:
# asdf   sdfasdf             adfegds

# %%
a = "ABCDEFG"
b = a.lower()
print(b)
# Out:
# abcdefg

# %%
a = "asddf"
b = a.upper()
print(b)
# Out:
# ASDDF

# %%
d = "asdfdsb ,, adfesdc"
e = d.replace("," , "*")
print(e)
# Out:
# asdfdsb ** adfesdc

# %%
r = "adfs,easdfa,eafaeo"
j = r.split(",")
print(j)
# Out:
# ['adfs', 'easdfa', 'eafaeo']

# %%
"abc" in  "gdrislak; "
# Out:
# False

# %%
"adgerdsvdf" < "def" #jsut first character is compared of ascii values
# Out:
# True

# %%
print("We wanna print values in double quotes \"Hello\" ")
# Out:
# We wanna print values in double quotes "Hello"

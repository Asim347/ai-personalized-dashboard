# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/ai-personalized-dashboard/blob/main/Hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
print("Welcome", name, "to Python Programming!")
# Out:
# Enter your name: Asim Ali
# Welcome Asim Ali to Python Programming!
